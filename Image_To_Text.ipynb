# %%
# !pip install easyocr
# Out:
# Collecting easyocr
#   Downloading easyocr-1.6.0-py3-none-any.whl (21.0 MB)
# Collecting Shapely
#   Downloading Shapely-1.8.4-cp310-cp310-win_amd64.whl (1.3 MB)
# Requirement already satisfied: numpy in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from easyocr) (1.23.1)
# Requirement already satisfied: scipy in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from easyocr) (1.8.1)
# Requirement already satisfied: PyYAML in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from easyocr) (6.0)
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp310-cp310-win_amd64.whl (12.0 MB)
# Collecting ninja
#   Downloading ninja-1.10.2.3-py2.py3-none-win_amd64.whl (292 kB)
# Collecting opencv-python-headless<=4.5.4.60
#   Downloading opencv_python_headless-4.5.4.60-cp310-cp310-win_amd64.whl (35.0 MB)
# Requirement already satisfied: torch in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from easyocr) (1.12.1)
# Collecting python-bidi
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: torchvision>=0.5 in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from easyocr) (0.13.1)
# Requirement already satisfied: Pillow in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from easyocr) (9.2.0)
# Collecting pyclipper
#   Downloading pyclipper-1.3.0.post3-cp310-cp310-win_amd64.whl (94 kB)
# Requirement already satisfied: requests in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: typing-extensions in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from torchvision>=0.5->easyocr) (4.3.0)
# Requirement already satisfied: six in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.8.12-py3-none-any.whl (208 kB)
# Requirement already satisfied: networkx>=2.2 in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from scikit-image->easyocr) (2.8.6)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.21.1-py3-none-any.whl (3.4 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from scikit-image->easyocr) (21.3)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp310-cp310-win_amd64.whl (4.2 MB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\gagan dwaz\pycharmprojects\python_\venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.1.0)
# Installing collected packages: tifffile, PyWavelets, imageio, Shapely, scikit-image, python-bidi, pyclipper, opencv-python-headless, ninja, easyocr
# Successfully installed PyWavelets-1.3.0 Shapely-1.8.4 easyocr-1.6.0 imageio-2.21.1 ninja-1.10.2.3 opencv-python-headless-4.5.4.60 pyclipper-1.3.0.post3 python-bidi-0.4.2 scikit-image-0.19.3 tifffile-2022.8.12
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\Gagan Dwaz\PycharmProjects\Python_\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
Img_path = "iimggg.jpg"
reader = easyocr.Reader(["en"],gpu=True)
result = reader.readtext(Img_path)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# C:\Users\Gagan Dwaz\PycharmProjects\Python_\venv\lib\site-packages\torchvision\models\_utils.py:252: UserWarning: Accessing the model URLs via the internal dictionary of the module is deprecated since 0.13 and will be removed in 0.15. Please access them via the appropriate Weights Enum instead.
#   warnings.warn(
# C:\Users\Gagan Dwaz\PycharmProjects\Python_\venv\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Gagan Dwaz\PycharmProjects\Python_\venv\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# [([[140, 234], [462, 234], [462, 308], [140, 308]],
#   'SUMMER',
#   0.9999021296093923),
#  ([[143, 309], [215, 309], [215, 377], [143, 377]], 'IS', 0.9777443472283368),
#  ([[240, 308], [454, 308], [454, 380], [240, 380]],
#   'HEREI',
#   0.7801444335407267)]

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
img = cv2.imread(Img_path)
img = cv2.rectangle(img,top_left,bottom_right,(0,255,255),5)
img = cv2.putText(img,text,top_left,font,0.5,(255,255,255),2,cv2.LINE_AA)
plt.imshow(img)
plt.show()

# %%
# For Multiple Lines
for detection in result:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,255),5)
    img = cv2.putText(img,text,top_left,font,0.5,(255,255,255),2,cv2.LINE_AA)
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
